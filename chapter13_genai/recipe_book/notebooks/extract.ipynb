# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
from datetime import date
from weaviate.util import generate_uuid5

from langchain.schema import Document
from langchain.text_splitter import RecursiveCharacterTextSplitter

# %% [markdown]
# # Get the links of the articles

# %%
headers = {}
links = []
dates = []
page = 1

base_url = "https://www.astronomer.io"
page_url = base_url + "/blog/{page}/#archive"
blog_cutoff_date = date(2023,1,19)

response = requests.get(page_url.format(page=page), headers=headers)

while response.ok:
    soup = BeautifulSoup(response.text, "lxml")
    cards = soup.find_all(class_="post-card__cover")
    card_links = [base_url + card.find("a", href=True)["href"] for card in cards]
    links.extend(card_links)
    
    meta = soup.find_all(class_="post-card__meta")
    dates.extend([post.find("time")["datetime"] for post in meta])

    page = page + 1
    response = requests.get(page_url.format(page=page), headers=headers)

# %% [markdown]
# ## Format content into a pandas DF

# %%
df = (
    pd.DataFrame(zip(links, dates), columns=["docLink", "date"])
    .assign(date=lambda df: pd.to_datetime(df["date"]).dt.date)
    .loc[lambda df: df["date"] > blog_cutoff_date]
    .drop("date", axis=1)
    .drop_duplicates()
    .assign(
        raw_content = lambda df: [requests.get(link).content for link in df.docLink],
        title= lambda df: [BeautifulSoup(content, "lxml").find("h1").text for content in df.raw_content],
        text_content= lambda df: [BeautifulSoup(content, "lxml").find(class_="prose").get_text().replace("{{","{").replace("}}","}") for content in df.raw_content],
        content = lambda df:  "# " + df["title"] + "\n\n## " + df["text_content"],
        docSource = "astro blog",    
        sha = lambda df: [generate_uuid5(content) for content in df.content]
    )
    .reset_index(drop=True)
    .loc[:, ["docSource","sha","content", "docLink"]]
)

df
# Out:
#      docSource                                   sha  \
# 0   astro blog  436b9648-1c86-5c86-8a90-1c251d578774
# 1   astro blog  4017cd9d-86f5-5466-b7e5-e5a118bd290f
# 2   astro blog  f50b4035-7e41-58ed-8849-c1264bb90731
# 3   astro blog  bc361e11-6a60-5003-bb63-979247bc113d
# 4   astro blog  73f6958c-0a1a-529c-a54b-01398ea49a6d
# 5   astro blog  bbc8a530-73d6-5bc0-8a92-64dff1f18725
# 6   astro blog  caff2267-6c9a-5f11-ab2d-23f8d0c51cb4
# 7   astro blog  21878f4e-777c-5206-8e35-5491b2e9a4e9
# 8   astro blog  ff464c60-59a1-5365-a256-2aa68cf4b4e5
# 9   astro blog  af83215c-c624-5cd8-96de-cb3358aaf61a
# 10  astro blog  d353159b-480e-5bf5-9cbd-5bb7cafb5774
# 11  astro blog  11ec6f82-13fb-5294-8c39-cc5baf5f1ca5
# 12  astro blog  59819876-953a-567c-9c4b-1730db9a1704
# 13  astro blog  d9f2d1cf-d59c-51d3-aa33-03c4f96f0c65
# 14  astro blog  ac26e537-fbd8-582c-ac3c-972ac42b00b7
# 15  astro blog  5cef0aa8-5242-58f1-b559-93b96ae1e1ff
# 16  astro blog  f4e65a40-f6a3-5c23-8bc4-ca980c3a5183
# 17  astro blog  1e05e21f-aae6-59f2-91dd-c42902497561
# 18  astro blog  d731bd20-5bce-594f-a31a-55fa2c11e0eb
# 19  astro blog  c17af15f-a7c5-5597-928c-a0b884154117
# 20  astro blog  a43646f3-dfb7-59b2-8151-79b9f5c8c935
# 21  astro blog  894039bc-9978-5093-b669-2f88a39e1475
# 22  astro blog  3cbc33c9-fbb7-53d7-9117-bf558cbda559
# 23  astro blog  27449546-42a1-5eff-a589-41632553e97b
# 24  astro blog  4b423b86-8c2c-5882-987a-6a66053f6b28
# 25  astro blog  e37ccd77-f35f-53a0-8bf1-c8bab168e95f
# 26  astro blog  9875fe85-dc61-5340-a1d4-b635dfbb6ec7
# 27  astro blog  b1fa6f34-41e0-5871-8dd7-65669cfeeef4
# 28  astro blog  cb4f1e28-b0fb-55d8-a7f3-3a97a7124633
# 29  astro blog  c70b842a-2a4b-54d7-b9e8-19f57e96b458
# 30  astro blog  56c8545c-6c8f-58cc-974c-3cceeb5cf99c
# 31  astro blog  e738a9c0-4cb4-5435-a988-7c55f1c39897
# 32  astro blog  70e4fb1a-e7e9-5161-acd9-daa07f1e2011
# 33  astro blog  4dd9ed98-7b69-5aae-a60b-f9e96a05b968
# 34  astro blog  ae2af8af-ec0c-55f9-a61e-33824bc84be7
# 35  astro blog  b29e6958-8f1e-595c-a193-b59b1e40e056
# 36  astro blog  3b555561-8ea2-5eb6-a09d-da0df7e8145b
# 37  astro blog  300acbaf-4afb-59ff-b337-f36363592a83
# 38  astro blog  b4bf8828-f3e0-506d-8950-aedd0b2e59e2
# 39  astro blog  cc4473b1-91eb-5249-8012-cfc6b6e33a11
# 40  astro blog  8dcf9888-22b4-568d-90e7-85fc84e401b9
#
#                                               content  \
# 0   # Introducing Apache Airflow™ on Astro – an Az...
# 1   # Apache Airflow TaskFlow API vs. Traditional ...
# 2   # Orchestrating Feature Pipelines: Announcing ...
# 3   # Ask Astro: Operationalizing Data Ingest for ...
# 4   # Using Astronomer’s new Cosmos to deploy dbt ...
# 5   # Databricks vs. Airflow From a Management Per...
# 6   # Migrate Python Jobs to Airflow in 4 Simple S...
# 7   # 3 Key Takeaways from Airflow Summit 2023\n\n...
# 8   # Ask Astro: An open source LLM Application wi...
# 9   # Day 2 Operations for LLMs with Apache Airflo...
# 10  # Change Data Capture with Airflow - Part 2\n\...
# 11  # Comparing Data Orchestration: Databricks Wor...
# 12  # Debugging Airflow Made Easy: 3 Key Steps to ...
# 13  # Orchestrating Machine Learning Pipelines wit...
# 14  # Change Data Capture in Apache Airflow - Part...
# 15  # Introducing Airflow 2.7\n\n## Apache Airflow...
# 16  # Leveraging Apache Airflow and Kubernetes for...
# 17  # Test Airflow Upgrades with the Astro CLI\n\n...
# 18  # Enhanced Astro Workspace Roles for more gran...
# 19  # ETL in Airflow: A Comprehensive Guide to Eff...
# 20  # Run ETL with Astro and CrateDB Cloud in 30mi...
# 21  # Introducing Cosmos 1.0: the best way to run ...
# 22  # 6 Lessons Learned in Building Astronomer’s D...
# 23  # Expert tips for monitoring the health and SL...
# 24  # Advantages of Hosted Airflow for Your ETL Wo...
# 25  # Best Practices for Building an Airflow Servi...
# 26  # Astronomer and Fivetran Partner to Release P...
# 27  # Astronomer and Snowflake: Unleash the Power ...
# 28  # Three ways to use Airflow with MotherDuck an...
# 29  # The Astro Cloud IDE: from Python and SQL to ...
# 30  # The Top 7 Alternatives to MWAA\n\n## Streaml...
# 31  # The Top 7 Alternatives to Google Cloud Compo...
# 32  # How we optimized the Registry for performanc...
# 33  # Scale Airflow with confidence using Astro’s ...
# 34  # Introducing Airflow 2.6\n\n## Apache Airflow...
# 35  # Kubernetes Executor Support in Astro: A New ...
# 36  # CI/CD Enforcement for Code Changes\n\n## Con...
# 37  # OpenLineage Is on the Rise in 2023\n\n## If ...
# 38  # Inside Authorized Workspaces, A New Feature ...
# 39  # Introducing Support for the Kubernetes Execu...
# 40  # Get Improved Data Quality Checks in Airflow ...
#
#                                               docLink
# 0   https://www.astronomer.io/blog/introducing-apa...
# 1   https://www.astronomer.io/blog/apache-airflow-...
# 2   https://www.astronomer.io/blog/orchestrating-f...
# 3   https://www.astronomer.io/blog/ask-astro-opera...
# 4   https://www.astronomer.io/blog/using-astronome...
# 5   https://www.astronomer.io/blog/databricks-vs-a...
# 6   https://www.astronomer.io/blog/migrate-python-...
# 7   https://www.astronomer.io/blog/3-Key-Takeaways...
# 8   https://www.astronomer.io/blog/ask-astro-open-...
# 9   https://www.astronomer.io/blog/day-2-operation...
# 10  https://www.astronomer.io/blog/change-data-cap...
# 11  https://www.astronomer.io/blog/comparing-data-...
# 12  https://www.astronomer.io/blog/debugging-airfl...
# 13  https://www.astronomer.io/blog/orchestrating-m...
# 14  https://www.astronomer.io/blog/change-data-cap...
# 15  https://www.astronomer.io/blog/introducing-air...
# 16  https://www.astronomer.io/blog/leveraging-apac...
# 17  https://www.astronomer.io/blog/test-airflow-up...
# 18  https://www.astronomer.io/blog/introducing-upd...
# 19  https://www.astronomer.io/blog/etl-in-airflow-...
# 20  https://www.astronomer.io/blog/run-etlelt-with...
# 21  https://www.astronomer.io/blog/introducing-cos...
# 22  https://www.astronomer.io/blog/6-lessons-learn...
# 23  https://www.astronomer.io/blog/expert-tips-for...
# 24  https://www.astronomer.io/blog/advantages-of-h...
# 25  https://www.astronomer.io/blog/best-practices-...
# 26  https://www.astronomer.io/blog/astronomer-five...
# 27  https://www.astronomer.io/blog/astronomer-and-...
# 28  https://www.astronomer.io/blog/three-ways-to-u...
# 29  https://www.astronomer.io/blog/cloud-ide-new-c...
# 30  https://www.astronomer.io/blog/the-top-7-alter...
# 31  https://www.astronomer.io/blog/the-top-7-alter...
# 32  https://www.astronomer.io/blog/how-we-optimize...
# 33  https://www.astronomer.io/blog/scale-airflow-w...
# 34  https://www.astronomer.io/blog/introducing-air...
# 35  https://www.astronomer.io/blog/introducing-kub...
# 36  https://www.astronomer.io/blog/ci-cd-enforceme...
# 37  https://www.astronomer.io/blog/openlineage-is-...
# 38  https://www.astronomer.io/blog/inside-authoriz...
# 39  https://www.astronomer.io/blog/introducing-sup...
# 40  https://www.astronomer.io/blog/improved-data-q...

# %% [markdown]
# ## Split in chunks

# %%
splitter = RecursiveCharacterTextSplitter(chunk_size=4000, chunk_overlap=200, separators=["\n\n", "\n", " ", ""])

df = (
    df
    .assign( doc_chunks = lambda df: df["content"].apply(lambda x: splitter.split_documents([Document(page_content=x)])))
    .explode("doc_chunks", ignore_index=True)
    .assign( content = lambda df: df["doc_chunks"].apply(lambda x: x.page_content))
    .drop(["doc_chunks"], axis=1)
    .reset_index(drop=True)
)

df
# Out:
#       docSource                                   sha  \
# 0    astro blog  436b9648-1c86-5c86-8a90-1c251d578774
# 1    astro blog  436b9648-1c86-5c86-8a90-1c251d578774
# 2    astro blog  436b9648-1c86-5c86-8a90-1c251d578774
# 3    astro blog  436b9648-1c86-5c86-8a90-1c251d578774
# 4    astro blog  4017cd9d-86f5-5466-b7e5-e5a118bd290f
# ..          ...                                   ...
# 124  astro blog  cc4473b1-91eb-5249-8012-cfc6b6e33a11
# 125  astro blog  8dcf9888-22b4-568d-90e7-85fc84e401b9
# 126  astro blog  8dcf9888-22b4-568d-90e7-85fc84e401b9
# 127  astro blog  8dcf9888-22b4-568d-90e7-85fc84e401b9
# 128  astro blog  8dcf9888-22b4-568d-90e7-85fc84e401b9
#
#                                                content  \
# 0    # Introducing Apache Airflow™ on Astro – an Az...
# 1    How to Get Started\nGetting started is easy, a...
# 2    The top-level entity in Astro is an Organizati...
# 3    First-class support for Azure Private Networki...
# 4    # Apache Airflow TaskFlow API vs. Traditional ...
# ..                                                 ...
# 124  # Introducing Support for the Kubernetes Execu...
# 125  # Get Improved Data Quality Checks in Airflow ...
# 126  At Astronomer, we use Great Expectations for s...
# 127  gx_data_quality_checks = GreatExpectationsOper...
# 128  Figure 3. Screenshot of the Lineage graph in t...
#
#                                                docLink
# 0    https://www.astronomer.io/blog/introducing-apa...
# 1    https://www.astronomer.io/blog/introducing-apa...
# 2    https://www.astronomer.io/blog/introducing-apa...
# 3    https://www.astronomer.io/blog/introducing-apa...
# 4    https://www.astronomer.io/blog/apache-airflow-...
# ..                                                 ...
# 124  https://www.astronomer.io/blog/introducing-sup...
# 125  https://www.astronomer.io/blog/improved-data-q...
# 126  https://www.astronomer.io/blog/improved-data-q...
# 127  https://www.astronomer.io/blog/improved-data-q...
# 128  https://www.astronomer.io/blog/improved-data-q...
#
# [129 rows x 4 columns]

# %%
df.to_parquet("../dags/astro_blog.parquet")

# %%
a = pd.read_parquet("/Users/icabral/repos/VectorVault/dags/astro_blog.parquet").to_dict(orient="records")

# %%
[pd.read_parquet("./dags/astro_blog.parquet").to_dict(orient="records")[0:1]

# %%
len(a[28:29][0]["content"])

# %%
a[28]['content'][8400:8450]

# %%
a
